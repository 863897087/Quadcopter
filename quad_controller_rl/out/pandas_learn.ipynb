# %%
import pandas as pd
import matplotlib

# %%
action = pd.read_csv("action_2019-04-23_20-44-10.csv")
reward = pd.read_csv("reward_2019-04-23_20-44-10.csv")
#status = pd.read_csv("status_2019-04-20_16-14-44.csv")

# %%
display(reward.values.shape)
display(action.values.shape)
#display(status.values.shape)
# Out:
# (3824, 2)
# (82143, 14)

# %%
#reward = reward.drop( index=range(reward.values.shape[0]-100) )
#action = action.drop( index=range(action.values.shape[0]-100) )
#status = status.drop( index=range(status.values.shape[0]-200) )

# %%
reward[['total_reward']].plot(title="Episode Rewards")

# %%
status[['target','current']].plot(title='Episode Z')

# %%
action[['noise']].plot(title="stddev line")

# %%
action[['l1','l1c']].plot(title="X Line")

# %%
action[['l2','l2c']].plot(title="Y Line")

# %%
action[['l3','l3c']].plot(title="Z Line")
